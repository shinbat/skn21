# %% [markdown]
# # 성능개선 기법 실습

# %% [markdown]
# # 모듈 정의

# %% [markdown]
# ## train.py
#
# -   모델 학습과 검증 함수 정의

# %%
import os

os.makedirs("module", exist_ok=True)

# %%
# %%writefile module/train.py

import torch
import time

def test_multi_classification(dataloader, model, loss_fn, device="cpu") -> tuple:
    """
    다중 분류 검증/평가 함수
    
    Args:
        dataloader: DataLoader - 검증할 대상 데이터로더
        model: 검증할 모델
        loss_fn: 모델 추정값과 정답의 차이를 계산할 loss 함수.
        device: str - 연산을 처리할 장치. default-"cpu", gpu-"cuda"
    Returns:
        tuple: (loss, accuracy)
    """
    model.to(device)
    model.eval() 
    size = len(dataloader.dataset)
    num_steps = len(dataloader)
    
    test_loss, test_accuracy = 0., 0.
    
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            # 정확도 계산
            pred_label = torch.argmax(pred, axis=-1)
            test_accuracy += torch.sum(pred_label == y).item()
            
        test_loss /= num_steps
        test_accuracy /= size
    return test_loss, test_accuracy

def test_binary_classification(dataloader, model, loss_fn, device="cpu") -> tuple:
    """
    이진 분류 검증/평가 함수
    
    Args:
        dataloader: DataLoader - 검증할 대상 데이터로더
        model: 검증할 모델
        loss_fn: 모델 추정값과 정답의 차이를 계산할 loss 함수.
        device: str - 연산을 처리할 장치. default-"cpu", gpu-"cuda"
    Returns:
        tuple: (loss, accuracy)
    """
    model.to(device)
    model.eval() # 모델을 평가모드로 변환
    size = len(dataloader.dataset)
    num_steps = len(dataloader)
    
    test_loss, test_accuracy = 0., 0.
    
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            ## 정확도 계산
            pred_label = (pred >= 0.5).type(torch.int32)
            test_accuracy += (pred_label == y).sum().item() 
            
        test_loss /= num_steps
        test_accuracy /= size   #전체 개수로 나눈다.
    return test_loss, test_accuracy    

def train(dataloader, model, loss_fn, optimizer, device="cpu", mode:"binary or multi"='binary'):
    """
    모델을 1 epoch 학습시키는 함수

    Args:
        dataloader: DataLoader - 학습데이터셋을 제공하는 DataLoader
        model - 학습대상 모델
        loss_fn: 모델 추정값과 정답의 차이를 계산할 loss 함수.
        optimizer - 최적화 함수
        device: str - 연산을 처리할 장치. default-"cpu", gpu-"cuda"
        mode: str - 분류 종류. binary 또는 multi
    
    Returns:
        tuple: 학습후 계산한 Train set에 대한  train_loss, train_accuracy
    """
    model.train()

    for X, y in dataloader:
        X, y = X.to(device), y.to(device)
        pred = model(X)

        loss = loss_fn(pred, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    if mode == 'binary':
        train_loss, train_accuracy = test_binary_classification(dataloader, model, loss_fn, device)
    else:
        train_loss, train_accuracy = test_multi_classification(dataloader, model, loss_fn, device)
    return train_loss, train_accuracy



def fit(train_loader, val_loader, model, loss_fn, optimizer, epochs, save_best_model=True, 
        save_model_path=None, early_stopping=True, patience=10, device='cpu',  mode:"binary or multi"='binary',
        lr_scheduler=None):
    """
    모델을 학습시키는 함수

    Args:
        train_loader (Dataloader): Train dataloader
        test_loader (Dataloader): validation dataloader
        model (Module): 학습시킬 모델
        loss_fn (_Loss): Loss function
        optimizer (Optimizer): Optimizer
        epochs (int): epoch수
        save_best_model (bool, optional): 학습도중 성능개선시 모델 저장 여부. Defaults to True.
        save_model_path (str, optional): save_best_model=True일 때 모델저장할 파일 경로. Defaults to None.
        early_stopping (bool, optional): 조기 종료 여부. Defaults to True.
        patience (int, optional): 조기종료 True일 때 종료전에 성능이 개선될지 몇 epoch까지 기다릴지 epoch수. Defaults to 10.
        device (str, optional): device. Defaults to 'cpu'.
        mode(str, optinal): 분류 종류. "binary(default) or multi
        lr_scheduler: Learning Rate Scheduler 객체. default: None, Epoch 단위로 LR 를 변경.
    
    Returns:
        tuple: 에폭 별 성능 리스트. (train_loss_list, train_accuracy_list, validation_loss_list, validataion_accuracy_list)
    """

    train_loss_list = []
    train_accuracy_list = []
    val_loss_list = []
    val_accuracy_list = []
    
        
    if save_best_model:
        best_score_save = torch.inf

    ############################
    # early stopping
    #############################
    if early_stopping:
        trigger_count = 0
        best_score_es = torch.inf
    
    # 모델 device로 옮기기
    model = model.to(device)
    s = time.time()
    for epoch in range(epochs):

        ######### train
        train_loss, train_accuracy = train(train_loader, model, loss_fn, optimizer, device=device, mode=mode)
        ############ 1 epoch 학습 종료 -> LR 를 변경 ###########
        if lr_scheduler is not None:
            current_lr = lr_scheduler.get_last_lr()[0]  # log용
            lr_scheduler.step()
            new_lr = lr_scheduler.get_last_lr()[0] # log용
            if current_lr != new_lr: # LR가 변경되었으면
                print(f">>>>>>Learning Rate가 {current_lr}에서 {new_lr}로 변경됨<<<<<<")

        ########## 검증
        if mode == "binary":
            val_loss, val_accuracy = test_binary_classification(val_loader, model, loss_fn, device=device)
        else:
            val_loss, val_accuracy = test_multi_classification(val_loader, model, loss_fn, device=device)

        train_loss_list.append(train_loss)
        train_accuracy_list.append(train_accuracy)
        val_loss_list.append(val_loss)
        val_accuracy_list.append(val_accuracy)
        
        print(f"Epoch[{epoch+1}/{epochs}] - Train loss: {train_loss:.5f} Train Accucracy: {train_accuracy:.5f} || Validation Loss: {val_loss:.5f} Validation Accuracy: {val_accuracy:.5f}")
        print('='*100)
        
        # 모델 저장
        if save_best_model:
            if val_loss < best_score_save:
                torch.save(model, save_model_path)
                print(f"저장: {epoch+1} - 이전 : {best_score_save}, 현재: {val_loss}")
                best_score_save = val_loss
        
        # early stopping 처리            
        if early_stopping:
            if val_loss < best_score_es: 
                best_score_es = val_loss  
                trigger_count = 0
                                
            else:
                trigger_count += 1                
                if patience == trigger_count:
                    print(f"Early stopping: Epoch - {epoch}")
                    break
            
    e = time.time()
    print(e-s, "초")
    return train_loss_list, train_accuracy_list, val_loss_list, val_accuracy_list
# Out:
# Writing module/train.py

# %% [markdown]
# ## data.py
#
# -   dataset 생성 함수 제공 모듈

# %%
# %%writefile module/data.py

from torchvision import datasets, transforms
from torch.utils.data import DataLoader

def load_mnist_dataset(root_path, batch_size, is_train=True):
    """
    mnist dataset dataloader 제공 함수
    Args:
        root_path: str|Path - 데이터파일 저장 디렉토리
        batch_size: int
        is_train: bool = True - True: Train dataset, False - Test dataset
    
    Returns:
        DataLoader 
    """
    transform = transforms.Compose([
        transforms.ToTensor()
    ])
    dataset = datasets.MNIST(root=root_path, train=is_train, download=True, transform=transform)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=is_train, drop_last=is_train)  # shuffle: train이면 True, test면 False 할 것이므로 is_train을 넣음.
    
    return dataloader

def load_fashion_mnist_dataset(root_path, batch_size, is_train=True):
    """
    fashion mnist dataset dataloader 제공 함수
    Args:
        root_path: str|Path - 데이터파일 저장 디렉토리
        batch_size: int
        is_train: bool = True - True: Train dataset, False - Test dataset
    
    Returns:
        DataLoader
    """
    transform = transforms.Compose([
        transforms.ToTensor()
    ])
    dataset = datasets.FashionMNIST(root=root_path, train=is_train, download=True, transform=transform)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=is_train, drop_last=is_train)  # shuffle: train이면 True, test면 False 할 것이므로 is_train을 넣음.
    
    return dataloader
# Out:
# Overwriting module/data.py

# %% [markdown]
# ## utils.py

# %%
# %%writefile module/utils.py
# 학습 결과를 시각화하는 함수.
import matplotlib.pyplot as plt

def plot_fit_result(train_loss_list, train_accuracy_list, valid_loss_list, valid_accuracy_list):
    """epoch별 학습 결과를 시각화하는 함수
    epoch별 loss와 accuracy를 시각화한다.

    Args:
        train_loss_list (list): Epoch별 train loss
        train_accuracy_list (list): Epoch별 train accuracy
        valid_loss_list (list): Epoch별 validation loss
        valid_accuracy_list (list): Epoch별 validation accuracy
    """
    epoch = len(train_loss_list)
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(range(epoch), train_loss_list, label="train loss")
    plt.plot(range(epoch), valid_loss_list, label="validation loss")
    plt.title("Loss")
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.grid(True, linestyle=':')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(range(epoch), train_accuracy_list, label="train accuracy")
    plt.plot(range(epoch), valid_accuracy_list, label="validation accuracy")
    plt.title("Accuracy")
    plt.xlabel("epoch")
    plt.ylabel("accuracy")
    plt.grid(True, linestyle=':')
    plt.legend()

    plt.tight_layout()
    plt.show()
# Out:
# Writing module/utils.py

# %% [markdown]
# ## Import

# %%
import torch
import torch.nn as nn
from torchinfo import summary

from module.train import fit
from module.data import load_mnist_dataset, load_fashion_mnist_dataset
from module.utils import plot_fit_result

# %% [markdown]
# ## 하이퍼파라미터, 변수 정의

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
root_data_path = "datasets"

epochs = 100
batch_size = 256
lr = 0.001

# %% [markdown]
# # Data 준비
#
# ## mnist 데이터 로딩

# %%
train_loader = load_mnist_dataset(root_data_path, batch_size)
test_loader = load_mnist_dataset(root_data_path, batch_size, False)

## Fashion Mnist
# train_loader = load_fashion_mnist_dataset(root_data_path, batch_size)
# test_loader = load_fashion_mnist_dataset(root_data_path, batch_size, False)
# Out:
# 100%|██████████| 9.91M/9.91M [00:04<00:00, 2.12MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 141kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.44MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 17.9MB/s]

# %%
len(train_loader.dataset)
# Out:
# 60000

# %%
classes = train_loader.dataset.classes
class_to_idx = train_loader.dataset.class_to_idx

# %%
class_to_idx
# Out:
# {'0 - zero': 0,
#  '1 - one': 1,
#  '2 - two': 2,
#  '3 - three': 3,
#  '4 - four': 4,
#  '5 - five': 5,
#  '6 - six': 6,
#  '7 - seven': 7,
#  '8 - eight': 8,
#  '9 - nine': 9}

# %% [markdown]
# # 모델의 크기 변경에 따른 성능변화
# ## 작은 모델

# %%
class SmallModel(nn.Module):

    def __init__(self):
        super().__init__()
        self.lr1 = nn.Linear(784, 16)
        self.lr2 = nn.Linear(16, 10)
        self.relu = nn.ReLU()
    
    def forward(self, X):
        out = nn.Flatten()(X)   #(N, 1, 28, 28) -> (N, 1, 28*28)
        out = self.relu(self.lr1(out))
        out = self.lr2(out)
        return out

# %%
summary(SmallModel(), (100, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# SmallModel                               [100, 10]                 --
# ├─Linear: 1-1                            [100, 16]                 12,560
# ├─ReLU: 1-2                              [100, 16]                 --
# ├─Linear: 1-3                            [100, 10]                 170
# ==========================================================================================
# Total params: 12,730
# Trainable params: 12,730
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 1.27
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 0.02
# Params size (MB): 0.05
# Estimated Total Size (MB): 0.39
# ==========================================================================================

# %%
small_model = SmallModel()
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(small_model.parameters(), lr=lr)

# %%
result = fit(train_loader, test_loader, small_model, loss_fn, optimizer, epochs,
             save_best_model=False, device=device, mode='multi')
# Out:
# Epoch[1/100] - Train loss: 0.41575 Train Accucracy: 0.88922 || Validation Loss: 0.39969 Validation Accuracy: 0.89600
# ====================================================================================================
# Epoch[2/100] - Train loss: 0.31997 Train Accucracy: 0.90850 || Validation Loss: 0.30962 Validation Accuracy: 0.91150
# ====================================================================================================
# Epoch[3/100] - Train loss: 0.28656 Train Accucracy: 0.91765 || Validation Loss: 0.27893 Validation Accuracy: 0.92120
# ====================================================================================================
# Epoch[4/100] - Train loss: 0.26925 Train Accucracy: 0.92293 || Validation Loss: 0.26568 Validation Accuracy: 0.92490
# ====================================================================================================
# Epoch[5/100] - Train loss: 0.25546 Train Accucracy: 0.92593 || Validation Loss: 0.25576 Validation Accuracy: 0.92730
# ====================================================================================================
# Epoch[6/100] - Train loss: 0.24397 Train Accucracy: 0.92908 || Validation Loss: 0.24500 Validation Accuracy: 0.93060
# ====================================================================================================
# Epoch[7/100] - Train loss: 0.23655 Train Accucracy: 0.93197 || Validation Loss: 0.23993 Validation Accuracy: 0.93080
# ====================================================================================================
# Epoch[8/100] - Train loss: 0.22469 Train Accucracy: 0.93513 || Validation Loss: 0.23029 Validation Accuracy: 0.93330
# ====================================================================================================
# Epoch[9/100] - Train loss: 0.21585 Train Accucracy: 0.93820 || Validation Loss: 0.22415 Validation Accuracy: 0.93440
# ====================================================================================================
# Epoch[10/100] - Train loss: 0.20866 Train Accucracy: 0.93965 || Validation Loss: 0.21841 Validation Accuracy: 0.93750
# ====================================================================================================
# Epoch[11/100] - Train loss: 0.20277 Train Accucracy: 0.94083 || Validation Loss: 0.21455 Validation Accuracy: 0.93570
# ====================================================================================================
# Epoch[12/100] - Train loss: 0.19454 Train Accucracy: 0.94328 || Validation Loss: 0.20759 Validation Accuracy: 0.93880
# ====================================================================================================
# Epoch[13/100] - Train loss: 0.18840 Train Accucracy: 0.94543 || Validation Loss: 0.20092 Validation Accuracy: 0.94080
# ====================================================================================================
# Epoch[14/100] - Train loss: 0.18161 Train Accucracy: 0.94790 || Validation Loss: 0.19599 Validation Accuracy: 0.93990
# ====================================================================================================
# Epoch[15/100] - Train loss: 0.17995 Train Accucracy: 0.94768 || Validation Loss: 0.19595 Validation Accuracy: 0.94210
# ====================================================================================================
# Epoch[16/100] - Train loss: 0.17284 Train Accucracy: 0.94985 || Validation Loss: 0.19033 Validation Accuracy: 0.94320
# ====================================================================================================
# Epoch[17/100] - Train loss: 0.16752 Train Accucracy: 0.95078 || Validation Loss: 0.18486 Validation Accuracy: 0.94500
# ====================================================================================================
# Epoch[18/100] - Train loss: 0.16540 Train Accucracy: 0.95163 || Validation Loss: 0.18704 Validation Accuracy: 0.94450
# ====================================================================================================
# Epoch[19/100] - Train loss: 0.16371 Train Accucracy: 0.95143 || Validation Loss: 0.18343 Validation Accuracy: 0.94440
# ====================================================================================================
# Epoch[20/100] - Train loss: 0.16072 Train Accucracy: 0.95260 || Validation Loss: 0.18272 Validation Accuracy: 0.94750
# ====================================================================================================
# Epoch[21/100] - Train loss: 0.15534 Train Accucracy: 0.95453 || Validation Loss: 0.17933 Validation Accuracy: 0.94740
# ====================================================================================================
# Epoch[22/100] - Train loss: 0.15241 Train Accucracy: 0.95488 || Validation Loss: 0.17518 Validation Accuracy: 0.94850
# ====================================================================================================
# Epoch[23/100] - Train loss: 0.15024 Train Accucracy: 0.95602 || Validation Loss: 0.17530 Validation Accuracy: 0.94870
# ====================================================================================================
# Epoch[24/100] - Train loss: 0.14743 Train Accucracy: 0.95605 || Validation Loss: 0.17372 Validation Accuracy: 0.94950
# ====================================================================================================
# Epoch[25/100] - Train loss: 0.14480 Train Accucracy: 0.95712 || Validation Loss: 0.17229 Validation Accuracy: 0.95060
# ====================================================================================================
# Epoch[26/100] - Train loss: 0.14230 Train Accucracy: 0.95868 || Validation Loss: 0.17151 Validation Accuracy: 0.95050
# ====================================================================================================
# Epoch[27/100] - Train loss: 0.14150 Train Accucracy: 0.95897 || Validation Loss: 0.17090 Validation Accuracy: 0.95050
# ====================================================================================================
# Epoch[28/100] - Train loss: 0.14162 Train Accucracy: 0.95737 || Validation Loss: 0.17119 Validation Accuracy: 0.95020
# ====================================================================================================
# Epoch[29/100] - Train loss: 0.13627 Train Accucracy: 0.96000 || Validation Loss: 0.16806 Validation Accuracy: 0.95100
# ====================================================================================================
# Epoch[30/100] - Train loss: 0.13485 Train Accucracy: 0.96065 || Validation Loss: 0.16816 Validation Accuracy: 0.95140
# ====================================================================================================
# Epoch[31/100] - Train loss: 0.13129 Train Accucracy: 0.96140 || Validation Loss: 0.16409 Validation Accuracy: 0.95230
# ====================================================================================================
# Epoch[32/100] - Train loss: 0.13037 Train Accucracy: 0.96137 || Validation Loss: 0.16504 Validation Accuracy: 0.95170
# ====================================================================================================
# Epoch[33/100] - Train loss: 0.12791 Train Accucracy: 0.96252 || Validation Loss: 0.16235 Validation Accuracy: 0.95200
# ====================================================================================================
# Epoch[34/100] - Train loss: 0.12765 Train Accucracy: 0.96208 || Validation Loss: 0.16430 Validation Accuracy: 0.95230
# ====================================================================================================
# Epoch[35/100] - Train loss: 0.12516 Train Accucracy: 0.96300 || Validation Loss: 0.16080 Validation Accuracy: 0.95320
# ====================================================================================================
# Epoch[36/100] - Train loss: 0.12315 Train Accucracy: 0.96372 || Validation Loss: 0.16174 Validation Accuracy: 0.95240
# ====================================================================================================
# Epoch[37/100] - Train loss: 0.12396 Train Accucracy: 0.96293 || Validation Loss: 0.16298 Validation Accuracy: 0.95180
# ====================================================================================================
# Epoch[38/100] - Train loss: 0.12182 Train Accucracy: 0.96380 || Validation Loss: 0.16121 Validation Accuracy: 0.95180
# ====================================================================================================
# Epoch[39/100] - Train loss: 0.11949 Train Accucracy: 0.96468 || Validation Loss: 0.15923 Validation Accuracy: 0.95350
# ====================================================================================================
# Epoch[40/100] - Train loss: 0.11831 Train Accucracy: 0.96462 || Validation Loss: 0.16116 Validation Accuracy: 0.95240
# ====================================================================================================
# Epoch[41/100] - Train loss: 0.11554 Train Accucracy: 0.96627 || Validation Loss: 0.15906 Validation Accuracy: 0.95350
# ====================================================================================================
# Epoch[42/100] - Train loss: 0.11550 Train Accucracy: 0.96595 || Validation Loss: 0.15848 Validation Accuracy: 0.95320
# ====================================================================================================
# Epoch[43/100] - Train loss: 0.11474 Train Accucracy: 0.96625 || Validation Loss: 0.16092 Validation Accuracy: 0.95330
# ====================================================================================================
# Epoch[44/100] - Train loss: 0.11373 Train Accucracy: 0.96615 || Validation Loss: 0.16017 Validation Accuracy: 0.95450
# ====================================================================================================
# Epoch[45/100] - Train loss: 0.11290 Train Accucracy: 0.96595 || Validation Loss: 0.16048 Validation Accuracy: 0.95400
# ====================================================================================================
# Epoch[46/100] - Train loss: 0.10999 Train Accucracy: 0.96737 || Validation Loss: 0.15652 Validation Accuracy: 0.95250
# ====================================================================================================
# Epoch[47/100] - Train loss: 0.10946 Train Accucracy: 0.96732 || Validation Loss: 0.15835 Validation Accuracy: 0.95340
# ====================================================================================================
# Epoch[48/100] - Train loss: 0.10754 Train Accucracy: 0.96790 || Validation Loss: 0.15775 Validation Accuracy: 0.95390
# ====================================================================================================
# Epoch[49/100] - Train loss: 0.10759 Train Accucracy: 0.96803 || Validation Loss: 0.15917 Validation Accuracy: 0.95370
# ====================================================================================================
# Epoch[50/100] - Train loss: 0.10636 Train Accucracy: 0.96797 || Validation Loss: 0.15656 Validation Accuracy: 0.95350
# ====================================================================================================
# Epoch[51/100] - Train loss: 0.10482 Train Accucracy: 0.96890 || Validation Loss: 0.15705 Validation Accuracy: 0.95400
# ====================================================================================================
# Epoch[52/100] - Train loss: 0.10442 Train Accucracy: 0.96832 || Validation Loss: 0.15763 Validation Accuracy: 0.95330
# ====================================================================================================
# Epoch[53/100] - Train loss: 0.10457 Train Accucracy: 0.96840 || Validation Loss: 0.15736 Validation Accuracy: 0.95360
# ====================================================================================================
# Epoch[54/100] - Train loss: 0.10279 Train Accucracy: 0.96937 || Validation Loss: 0.15787 Validation Accuracy: 0.95330
# ====================================================================================================
# Epoch[55/100] - Train loss: 0.10136 Train Accucracy: 0.96950 || Validation Loss: 0.15676 Validation Accuracy: 0.95390
# ====================================================================================================
# Epoch[56/100] - Train loss: 0.10143 Train Accucracy: 0.96923 || Validation Loss: 0.15686 Validation Accuracy: 0.95270
# ====================================================================================================
# Early stopping: Epoch - 55
# 800.5682809352875 초

# %%
plot_fit_result(result[0], result[1], result[2], result[3])

# %% [markdown]
# ## 큰모델

# %%
class BigModel(nn.Module):

    def __init__(self):
        super().__init__()
        self.b1 = nn.Sequential(nn.Flatten(), nn.Linear(784, 2048), nn.ReLU())
        self.b2 = nn.Sequential(nn.Linear(2048, 1024), nn.ReLU())
        self.b3 = nn.Sequential(nn.Linear(1024, 512), nn.ReLU())
        self.b4 = nn.Sequential(nn.Linear(512, 256), nn.ReLU())
        self.b5 = nn.Sequential(nn.Linear(256, 128), nn.ReLU())
        self.b6 = nn.Sequential(nn.Linear(128, 64), nn.ReLU())
        self.b7 = nn.Sequential(nn.Linear(64, 32), nn.ReLU())
        self.out_layer = nn.Linear(32, 10)

    def forward(self, X):
        out = self.b1(X)
        out = self.b2(out)
        out = self.b3(out)
        out = self.b4(out)
        out = self.b5(out)
        out = self.b6(out)
        out = self.b7(out)
        out = self.out_layer(out)
        return out

# %%
summary(BigModel(),   (256, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# BigModel                                 [256, 10]                 --
# ├─Sequential: 1-1                        [256, 2048]               --
# │    └─Flatten: 2-1                      [256, 784]                --
# │    └─Linear: 2-2                       [256, 2048]               1,607,680
# │    └─ReLU: 2-3                         [256, 2048]               --
# ├─Sequential: 1-2                        [256, 1024]               --
# │    └─Linear: 2-4                       [256, 1024]               2,098,176
# │    └─ReLU: 2-5                         [256, 1024]               --
# ├─Sequential: 1-3                        [256, 512]                --
# │    └─Linear: 2-6                       [256, 512]                524,800
# │    └─ReLU: 2-7                         [256, 512]                --
# ├─Sequential: 1-4                        [256, 256]                --
# │    └─Linear: 2-8                       [256, 256]                131,328
# │    └─ReLU: 2-9                         [256, 256]                --
# ├─Sequential: 1-5                        [256, 128]                --
# │    └─Linear: 2-10                      [256, 128]                32,896
# │    └─ReLU: 2-11                        [256, 128]                --
# ├─Sequential: 1-6                        [256, 64]                 --
# │    └─Linear: 2-12                      [256, 64]                 8,256
# │    └─ReLU: 2-13                        [256, 64]                 --
# ├─Sequential: 1-7                        [256, 32]                 --
# │    └─Linear: 2-14                      [256, 32]                 2,080
# │    └─ReLU: 2-15                        [256, 32]                 --
# ├─Linear: 1-8                            [256, 10]                 330
# ==========================================================================================
# Total params: 4,405,546
# Trainable params: 4,405,546
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.13
# ==========================================================================================
# Input size (MB): 0.80
# Forward/backward pass size (MB): 8.34
# Params size (MB): 17.62
# Estimated Total Size (MB): 26.77
# ==========================================================================================

# %%
d_model = BigModel()
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(big_model.parameters(), lr=lr)

# %%
result = fit(train_loader, test_loader, big_model, loss_fn, optimizer, epochs,
             save_best_model=False, device=device, mode='multi')
# Out:
# Epoch[1/100] - Train loss: 0.14430 Train Accucracy: 0.95623 || Validation Loss: 0.14992 Validation Accuracy: 0.95550
# ====================================================================================================
# Epoch[2/100] - Train loss: 0.08731 Train Accucracy: 0.97305 || Validation Loss: 0.11618 Validation Accuracy: 0.96590
# ====================================================================================================
# Epoch[3/100] - Train loss: 0.05628 Train Accucracy: 0.98213 || Validation Loss: 0.09627 Validation Accuracy: 0.97260
# ====================================================================================================
# Epoch[4/100] - Train loss: 0.04466 Train Accucracy: 0.98477 || Validation Loss: 0.08298 Validation Accuracy: 0.97630
# ====================================================================================================
# Epoch[5/100] - Train loss: 0.03898 Train Accucracy: 0.98675 || Validation Loss: 0.10564 Validation Accuracy: 0.97140
# ====================================================================================================
# Epoch[6/100] - Train loss: 0.03580 Train Accucracy: 0.98818 || Validation Loss: 0.09320 Validation Accuracy: 0.97770
# ====================================================================================================
# Epoch[7/100] - Train loss: 0.02264 Train Accucracy: 0.99162 || Validation Loss: 0.09106 Validation Accuracy: 0.97840
# ====================================================================================================
# Epoch[8/100] - Train loss: 0.01498 Train Accucracy: 0.99407 || Validation Loss: 0.08155 Validation Accuracy: 0.98030
# ====================================================================================================
# Epoch[9/100] - Train loss: 0.02113 Train Accucracy: 0.99215 || Validation Loss: 0.08719 Validation Accuracy: 0.97750
# ====================================================================================================
# Epoch[10/100] - Train loss: 0.02710 Train Accucracy: 0.99085 || Validation Loss: 0.09569 Validation Accuracy: 0.97660
# ====================================================================================================
# Epoch[11/100] - Train loss: 0.01777 Train Accucracy: 0.99312 || Validation Loss: 0.09206 Validation Accuracy: 0.98030
# ====================================================================================================
# Epoch[12/100] - Train loss: 0.01432 Train Accucracy: 0.99417 || Validation Loss: 0.09215 Validation Accuracy: 0.97830
# ====================================================================================================
# Epoch[13/100] - Train loss: 0.01618 Train Accucracy: 0.99337 || Validation Loss: 0.09441 Validation Accuracy: 0.97940
# ====================================================================================================
# Epoch[14/100] - Train loss: 0.01163 Train Accucracy: 0.99482 || Validation Loss: 0.09990 Validation Accuracy: 0.97990
# ====================================================================================================
# Epoch[15/100] - Train loss: 0.02939 Train Accucracy: 0.99057 || Validation Loss: 0.14258 Validation Accuracy: 0.97300
# ====================================================================================================
# Epoch[16/100] - Train loss: 0.01109 Train Accucracy: 0.99520 || Validation Loss: 0.09686 Validation Accuracy: 0.98180
# ====================================================================================================
# Epoch[17/100] - Train loss: 0.02313 Train Accucracy: 0.99155 || Validation Loss: 0.10461 Validation Accuracy: 0.97600
# ====================================================================================================
# Epoch[18/100] - Train loss: 0.02103 Train Accucracy: 0.99285 || Validation Loss: 0.11781 Validation Accuracy: 0.97590
# ====================================================================================================
# Early stopping: Epoch - 17
# 502.79427886009216 초

# %%
plot_fit_result(result[0], result[1], result[2], result[3])

# %% [markdown]
# # Dropout 예제
#
# -   dropout 각 레이어에 적용
#     -   dropout은 nn.Dropout 객체를 사용
#     -   객체 생성시 dropout_rate 설정: 0.2 ~ 0.5
#     -   Drop시킬 노드를 가진 Layer 뒤에 추가한다.

# %%
# Dropout Layer적용 : nn.Linear -> nn.ReLU -> nn.Dropout
class DropOutModel(nn.Module):

    def __init__(self, dropout_rate=0.5):
        super().__init__()
        self.b1 = nn.Sequential(nn.Flatten(), nn.Linear(784, 2048), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b2 = nn.Sequential(nn.Linear(2048, 1024), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b3 = nn.Sequential(nn.Linear(1024, 512), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b4 = nn.Sequential(nn.Linear(512, 256), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b5 = nn.Sequential(nn.Linear(256, 128), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b6 = nn.Sequential(nn.Linear(128, 64), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b7 = nn.Sequential(nn.Linear(64, 32), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.out_layer = nn.Linear(32, 10)

    def forward(self, X):
        out = self.b1(X)
        out = self.b2(out)
        out = self.b3(out)
        out = self.b4(out)
        out = self.b5(out)
        out = self.b6(out)
        out = self.b7(out)
        out = self.out_layer(out)
        return out

# %%
summary(DropOutModel(),   (256, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# DropOutModel                             [256, 10]                 --
# ├─Sequential: 1-1                        [256, 2048]               --
# │    └─Flatten: 2-1                      [256, 784]                --
# │    └─Linear: 2-2                       [256, 2048]               1,607,680
# │    └─ReLU: 2-3                         [256, 2048]               --
# │    └─Dropout: 2-4                      [256, 2048]               --
# ├─Sequential: 1-2                        [256, 1024]               --
# │    └─Linear: 2-5                       [256, 1024]               2,098,176
# │    └─ReLU: 2-6                         [256, 1024]               --
# │    └─Dropout: 2-7                      [256, 1024]               --
# ├─Sequential: 1-3                        [256, 512]                --
# │    └─Linear: 2-8                       [256, 512]                524,800
# │    └─ReLU: 2-9                         [256, 512]                --
# │    └─Dropout: 2-10                     [256, 512]                --
# ├─Sequential: 1-4                        [256, 256]                --
# │    └─Linear: 2-11                      [256, 256]                131,328
# │    └─ReLU: 2-12                        [256, 256]                --
# │    └─Dropout: 2-13                     [256, 256]                --
# ├─Sequential: 1-5                        [256, 128]                --
# │    └─Linear: 2-14                      [256, 128]                32,896
# │    └─ReLU: 2-15                        [256, 128]                --
# │    └─Dropout: 2-16                     [256, 128]                --
# ├─Sequential: 1-6                        [256, 64]                 --
# │    └─Linear: 2-17                      [256, 64]                 8,256
# │    └─ReLU: 2-18                        [256, 64]                 --
# │    └─Dropout: 2-19                     [256, 64]                 --
# ├─Sequential: 1-7                        [256, 32]                 --
# │    └─Linear: 2-20                      [256, 32]                 2,080
# │    └─ReLU: 2-21                        [256, 32]                 --
# │    └─Dropout: 2-22                     [256, 32]                 --
# ├─Linear: 1-8                            [256, 10]                 330
# ==========================================================================================
# Total params: 4,405,546
# Trainable params: 4,405,546
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.13
# ==========================================================================================
# Input size (MB): 0.80
# Forward/backward pass size (MB): 8.34
# Params size (MB): 17.62
# Estimated Total Size (MB): 26.77
# ==========================================================================================

# %%
d_model = DropOutModel()
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(d_model.parameters(), lr=lr)

# %%
result = fit(train_loader, test_loader, d_model, loss_fn, optimizer, epochs,
             save_best_model=False, device=device, mode='multi')
# Out:
# Epoch[1/100] - Train loss: 0.29688 Train Accucracy: 0.92937 || Validation Loss: 0.30922 Validation Accuracy: 0.93150
# ====================================================================================================
# Epoch[2/100] - Train loss: 0.18807 Train Accucracy: 0.95437 || Validation Loss: 0.21007 Validation Accuracy: 0.95410
# ====================================================================================================
# Epoch[3/100] - Train loss: 0.15002 Train Accucracy: 0.96220 || Validation Loss: 0.18227 Validation Accuracy: 0.95920
# ====================================================================================================
# Epoch[4/100] - Train loss: 0.13470 Train Accucracy: 0.96730 || Validation Loss: 0.16185 Validation Accuracy: 0.96540
# ====================================================================================================
# Epoch[5/100] - Train loss: 0.10465 Train Accucracy: 0.97277 || Validation Loss: 0.16143 Validation Accuracy: 0.96750
# ====================================================================================================
# Epoch[6/100] - Train loss: 0.10136 Train Accucracy: 0.97232 || Validation Loss: 0.14896 Validation Accuracy: 0.96890
# ====================================================================================================
# Epoch[7/100] - Train loss: 0.09059 Train Accucracy: 0.97663 || Validation Loss: 0.15609 Validation Accuracy: 0.97150
# ====================================================================================================
# Epoch[8/100] - Train loss: 0.07858 Train Accucracy: 0.97950 || Validation Loss: 0.13061 Validation Accuracy: 0.97600
# ====================================================================================================
# Epoch[9/100] - Train loss: 0.07232 Train Accucracy: 0.98020 || Validation Loss: 0.14178 Validation Accuracy: 0.97330
# ====================================================================================================
# Epoch[10/100] - Train loss: 0.06614 Train Accucracy: 0.98158 || Validation Loss: 0.13447 Validation Accuracy: 0.97430
# ====================================================================================================
# Epoch[11/100] - Train loss: 0.06979 Train Accucracy: 0.98078 || Validation Loss: 0.13580 Validation Accuracy: 0.97150
# ====================================================================================================
# Epoch[12/100] - Train loss: 0.06459 Train Accucracy: 0.98167 || Validation Loss: 0.14468 Validation Accuracy: 0.97440
# ====================================================================================================
# Epoch[13/100] - Train loss: 0.05865 Train Accucracy: 0.98362 || Validation Loss: 0.13403 Validation Accuracy: 0.97670
# ====================================================================================================
# Epoch[14/100] - Train loss: 0.05333 Train Accucracy: 0.98423 || Validation Loss: 0.12955 Validation Accuracy: 0.97620
# ====================================================================================================
# Epoch[15/100] - Train loss: 0.04482 Train Accucracy: 0.98708 || Validation Loss: 0.12006 Validation Accuracy: 0.97890
# ====================================================================================================
# Epoch[16/100] - Train loss: 0.05458 Train Accucracy: 0.98477 || Validation Loss: 0.12225 Validation Accuracy: 0.97770
# ====================================================================================================
# Epoch[17/100] - Train loss: 0.05006 Train Accucracy: 0.98517 || Validation Loss: 0.13905 Validation Accuracy: 0.97530
# ====================================================================================================
# Epoch[18/100] - Train loss: 0.04623 Train Accucracy: 0.98677 || Validation Loss: 0.13261 Validation Accuracy: 0.97880
# ====================================================================================================
# Epoch[19/100] - Train loss: 0.04140 Train Accucracy: 0.98747 || Validation Loss: 0.14301 Validation Accuracy: 0.97770
# ====================================================================================================
# Epoch[20/100] - Train loss: 0.03344 Train Accucracy: 0.98883 || Validation Loss: 0.12587 Validation Accuracy: 0.98080
# ====================================================================================================
# Epoch[21/100] - Train loss: 0.03442 Train Accucracy: 0.99010 || Validation Loss: 0.17454 Validation Accuracy: 0.98080
# ====================================================================================================
# Epoch[22/100] - Train loss: 0.03503 Train Accucracy: 0.98892 || Validation Loss: 0.11628 Validation Accuracy: 0.98040
# ====================================================================================================
# Epoch[23/100] - Train loss: 0.02766 Train Accucracy: 0.99105 || Validation Loss: 0.14464 Validation Accuracy: 0.98270
# ====================================================================================================
# Epoch[24/100] - Train loss: 0.03428 Train Accucracy: 0.98985 || Validation Loss: 0.13873 Validation Accuracy: 0.98130
# ====================================================================================================
# Epoch[25/100] - Train loss: 0.03087 Train Accucracy: 0.99033 || Validation Loss: 0.14327 Validation Accuracy: 0.97990
# ====================================================================================================
# Epoch[26/100] - Train loss: 0.02869 Train Accucracy: 0.99090 || Validation Loss: 0.12524 Validation Accuracy: 0.97980
# ====================================================================================================
# Epoch[27/100] - Train loss: 0.02680 Train Accucracy: 0.99152 || Validation Loss: 0.12421 Validation Accuracy: 0.98160
# ====================================================================================================
# Epoch[28/100] - Train loss: 0.02387 Train Accucracy: 0.99203 || Validation Loss: 0.11879 Validation Accuracy: 0.98330
# ====================================================================================================
# Epoch[29/100] - Train loss: 0.03233 Train Accucracy: 0.99070 || Validation Loss: 0.16659 Validation Accuracy: 0.98050
# ====================================================================================================
# Epoch[30/100] - Train loss: 0.02755 Train Accucracy: 0.99105 || Validation Loss: 0.13979 Validation Accuracy: 0.98170
# ====================================================================================================
# Epoch[31/100] - Train loss: 0.02157 Train Accucracy: 0.99267 || Validation Loss: 0.14420 Validation Accuracy: 0.98180
# ====================================================================================================
# Epoch[32/100] - Train loss: 0.02561 Train Accucracy: 0.99225 || Validation Loss: 0.16490 Validation Accuracy: 0.98270
# ====================================================================================================
# Early stopping: Epoch - 31
# 1067.7668464183807 초

# %%
plot_fit_result(result[0], result[1], result[2], result[3])

# %% [markdown]
# # Batch Normalization
#
# - Dense 와 Activation 사이에 정의한다.

# %%
import torch
import torch.nn as nn
from torchinfo import summary

# %%
# Dropout Layer적용 : nn.Linear -> nn.ReLU -> nn.Dropout
# BatchNorm1d Layer적용 : nn.Linear -> nn.BatchNorm1d-> nn.ReLU -> nn.Dropout
class BatchNormModel(nn.Module):

    def __init__(self, dropout_rate=0.5):
        super().__init__()
        self.b1 = nn.Sequential(nn.Flatten(), nn.Linear(784, 2048), nn.BatchNorm1d(2048), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b2 = nn.Sequential(nn.Linear(2048, 1024), nn.BatchNorm1d(1024), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b3 = nn.Sequential(nn.Linear(1024, 512), nn.BatchNorm1d(512), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b4 = nn.Sequential(nn.Linear(512, 256), nn.BatchNorm1d(256), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b5 = nn.Sequential(nn.Linear(256, 128), nn.BatchNorm1d(128), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b6 = nn.Sequential(nn.Linear(128, 64), nn.BatchNorm1d(64), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b7 = nn.Sequential(nn.Linear(64, 32), nn.BatchNorm1d(32), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.out_layer = nn.Linear(32, 10)

    def forward(self, X):
        out = self.b1(X)
        out = self.b2(out)
        out = self.b3(out)
        out = self.b4(out)
        out = self.b5(out)
        out = self.b6(out)
        out = self.b7(out)
        out = self.out_layer(out)
        return out

# %%
summary(BatchNormModel(),(256, 1, 28,28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# BatchNormModel                           [256, 10]                 --
# ├─Sequential: 1-1                        [256, 2048]               --
# │    └─Flatten: 2-1                      [256, 784]                --
# │    └─Linear: 2-2                       [256, 2048]               1,607,680
# │    └─BatchNorm1d: 2-3                  [256, 2048]               4,096
# │    └─ReLU: 2-4                         [256, 2048]               --
# │    └─Dropout: 2-5                      [256, 2048]               --
# ├─Sequential: 1-2                        [256, 1024]               --
# │    └─Linear: 2-6                       [256, 1024]               2,098,176
# │    └─BatchNorm1d: 2-7                  [256, 1024]               2,048
# │    └─ReLU: 2-8                         [256, 1024]               --
# │    └─Dropout: 2-9                      [256, 1024]               --
# ├─Sequential: 1-3                        [256, 512]                --
# │    └─Linear: 2-10                      [256, 512]                524,800
# │    └─BatchNorm1d: 2-11                 [256, 512]                1,024
# │    └─ReLU: 2-12                        [256, 512]                --
# │    └─Dropout: 2-13                     [256, 512]                --
# ├─Sequential: 1-4                        [256, 256]                --
# │    └─Linear: 2-14                      [256, 256]                131,328
# │    └─BatchNorm1d: 2-15                 [256, 256]                512
# │    └─ReLU: 2-16                        [256, 256]                --
# │    └─Dropout: 2-17                     [256, 256]                --
# ├─Sequential: 1-5                        [256, 128]                --
# │    └─Linear: 2-18                      [256, 128]                32,896
# │    └─BatchNorm1d: 2-19                 [256, 128]                256
# │    └─ReLU: 2-20                        [256, 128]                --
# │    └─Dropout: 2-21                     [256, 128]                --
# ├─Sequential: 1-6                        [256, 64]                 --
# │    └─Linear: 2-22                      [256, 64]                 8,256
# │    └─BatchNorm1d: 2-23                 [256, 64]                 128
# │    └─ReLU: 2-24                        [256, 64]                 --
# │    └─Dropout: 2-25                     [256, 64]                 --
# ├─Sequential: 1-7                        [256, 32]                 --
# │    └─Linear: 2-26                      [256, 32]                 2,080
# │    └─BatchNorm1d: 2-27                 [256, 32]                 64
# │    └─ReLU: 2-28                        [256, 32]                 --
# │    └─Dropout: 2-29                     [256, 32]                 --
# ├─Linear: 1-8                            [256, 10]                 330
# ==========================================================================================
# Total params: 4,413,674
# Trainable params: 4,413,674
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.13
# ==========================================================================================
# Input size (MB): 0.80
# Forward/backward pass size (MB): 16.67
# Params size (MB): 17.65
# Estimated Total Size (MB): 35.12
# ==========================================================================================

# %% [markdown]
# # Learning rate decay

# %% [markdown]
# ### Optimizer와 Learning rate scheduler의 속성, 메소드 확인
#
# -   파이토치는 `torch.optim` 모듈에서 다양한 Learning rate 알고리즘을 제공한다.

# %%
import matplotlib.pyplot as plt

def plot_lr(title, lr_list):
    """Learning 스케쥴러(학습도중 LR를 변경시키는 객체.)에 의해 변화되는 Learning Rate값을 시각화.

    Args:
        title (str): title
        lr_list (list): Learning Rate 스케쥴러에 의해 변경된 learning rate값들을 가지는 list
    """
    plt.figure(figsize=(15, 6))
    plt.plot(range(len(lr_list)), lr_list)

    plt.title(title)
    xticks = [x for x in range(len(lr_list)) if x % 10 == 0] # 눈금을 10 배수 자리에 위치.
    plt.xticks(xticks)
    plt.xlabel("Epoch 수 또는 Step 수")
    plt.ylabel("학습률-LR")
    plt.grid(True, linestyle=":")
    plt.show()

# %%
lr = 0.001
model =  BatchNormModel()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %%
# optimizer의 현재 lr 조회
optimizer.param_groups[0]['lr']
# Out:
# 0.001

# %% [markdown]
# #### StepLR

# %%
# 특정 epoch/step 마다 특정 비율로 lr를 변경(보통은 줄여나간다)
# LearningRate Scheduler 객체생성
step_lr_scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,      # 학습율을 변결할 옵티마이저
    step_size=30,   # 몇 epoch/step 당 lr을 변경할 지 설정.  lr_scheduler.step() - 지정한 횟수(30)만큼 호출하면 변경
    gamma=0.5       # 변경할 비율 . 새LR =  현재 lr * gamma
)
step_lr_scheduler.get_last_lr()     #optimizer현재 lr를 조회
# Out:
# [0.001]

# %%
# 학습
lr_list = [] # 스케줄러에게 lr 변경 요청후 lr를 저장
epochs = 300
step_size = 20      # for x,y in dataloader: 이 반복횟수
for epoch in range(epochs):
    # 1 에폭학습
    for step in range(step_size):
        # 배치만큼 학습데이터를 가져와서 1 step 학습
        # 1. x, y 를 device이동
        # 2 model 추론
        # 3 loss 계산
        # 4 파라미터들의 gradient계산
        # 5 파라미터 업데이트
        # 6 파라미터의 gradient 초기화
        optimizer.zero_grad()
    # lr 스케줄러를 이용해서 lr를 변경(스케줄에 맞춰서 변경)
    step_lr_scheduler.step()
    lr_list.append(step_lr_scheduler.get_last_lr()[0])
# Out:
# c:\py_repo\skn21\07_deeplearning_pytorch\.venv\Lib\site-packages\torch\optim\lr_scheduler.py:192: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(

# %%
lr_list
# Out:
# [0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  6.25e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  3.125e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  1.5625e-05,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  7.8125e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  3.90625e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  1.953125e-06,
#  9.765625e-07]

# %%
lr_list[-5:]
# Out:
# [1.953125e-06, 1.953125e-06, 1.953125e-06, 1.953125e-06, 9.765625e-07]

# %%
plt.rcParams['font.family'] = 'malgun gothic'
plt.rcParams['axes.unicode_minus'] = False
plot_lr('Step LR', lr_list)

# %% [markdown]
# #### CosineAnnealingLR
#
# cosine 그래프를 그리면서 learning rate를 변경 하는 방식.
# 최근에는 learning rate를 단순히 감소시키기 보다는 감소와 증가를 반복하여 진동하는 방식으로 최적점을 찾아가는 알고리즘을 많이 사용한다. 이러한 방법 중 가장 간단하면서도 많이 사용되는 방법이 CosineAnnealingLR이다.

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
ca_lr_sch = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=20,       # 변화주기 epoch/stop(내려가는주기, 올라가는주기)
    eta_min=1e-6,   # lr 최소값을 지정. 어디까지 내릴지
)
# 초기 lr ~ eta_min 사이를 올라갔다 내려갔다 한다

# %%
lr_list = []
for epoch in range(epochs):
    for step in range(step_size):
        optimizer.step()
        optimizer.zero_grad()
    ca_lr_sch.step()
    lr_list.append(ca_lr_sch.get_last_lr()[0])

# %%
lr_list
# Out:
# [0.0009938503261272714,
#  0.0009755527298894295,
#  0.0009455577588320899,
#  0.0009046039886902865,
#  0.0008536998372026806,
#  0.0007940987335200905,
#  0.0007272682546199038,
#  0.0006548539886902865,
#  0.0005786390152875956,
#  0.0005005000000000002,
#  0.000422360984712405,
#  0.00034614601130971394,
#  0.0002737317453800965,
#  0.00020690126647990978,
#  0.00014730016279731957,
#  9.639601130971382e-05,
#  5.54422411679103e-05,
#  2.5447270110570818e-05,
#  7.149673872728741e-06,
#  1e-06,
#  7.149673872728684e-06,
#  2.5447270110570706e-05,
#  5.544224116791024e-05,
#  9.639601130971376e-05,
#  0.00014730016279731944,
#  0.00020690126647990962,
#  0.00027373174538009633,
#  0.0003461460113097137,
#  0.00042236098471240465,
#  0.0005005,
#  0.0005786390152875953,
#  0.0006548539886902863,
#  0.0007272682546199037,
#  0.0007940987335200903,
#  0.0008536998372026804,
#  0.0009046039886902862,
#  0.0009455577588320897,
#  0.0009755527298894293,
#  0.0009938503261272714,
#  0.001,
#  0.0009938503261272714,
#  0.0009755527298894295,
#  0.00094555775883209,
#  0.0009046039886902868,
#  0.0008536998372026807,
#  0.0007940987335200906,
#  0.0007272682546199035,
#  0.0006548539886902864,
#  0.0005786390152875959,
#  0.0005005000000000001,
#  0.00042236098471240525,
#  0.0003461460113097139,
#  0.00027373174538009606,
#  0.00020690126647990973,
#  0.0001473001627973193,
#  9.639601130971384e-05,
#  5.54422411679105e-05,
#  2.5447270110570862e-05,
#  7.149673872728793e-06,
#  1e-06,
#  7.149673872728684e-06,
#  2.5447270110570536e-05,
#  5.544224116790985e-05,
#  9.639601130971277e-05,
#  0.00014730016279731773,
#  0.00020690126647990764,
#  0.00027373174538009335,
#  0.0003461460113097104,
#  0.0004223609847124011,
#  0.0005004999999999953,
#  0.0005786390152875904,
#  0.0006548539886902801,
#  0.0007272682546198963,
#  0.0007940987335200829,
#  0.0008536998372026722,
#  0.0009046039886902777,
#  0.0009455577588320811,
#  0.0009755527298894201,
#  0.000993850326127262,
#  0.0009999999999999907,
#  0.0009938503261272622,
#  0.0009755527298894207,
#  0.0009455577588320811,
#  0.0009046039886902783,
#  0.0008536998372026727,
#  0.0007940987335200835,
#  0.0007272682546198977,
#  0.0006548539886902815,
#  0.0005786390152875899,
#  0.0005004999999999957,
#  0.00042236098471240167,
#  0.00034614601130971096,
#  0.00027373174538009465,
#  0.00020690126647990732,
#  0.00014730016279731814,
#  9.639601130971306e-05,
#  5.544224116791007e-05,
#  2.5447270110570926e-05,
#  7.149673872728628e-06,
#  1e-06,
#  7.149673872728684e-06,
#  2.5447270110570208e-05,
#  5.5442241167909416e-05,
#  9.639601130971273e-05,
#  0.0001473001627973183,
#  0.00020690126647990827,
#  0.0002737317453800933,
#  0.00034614601130971036,
#  0.00042236098471239934,
#  0.0005004999999999962,
#  0.0005786390152875895,
#  0.0006548539886902802,
#  0.0007272682546198974,
#  0.0007940987335200825,
#  0.0008536998372026738,
#  0.0009046039886902782,
#  0.0009455577588320815,
#  0.0009755527298894203,
#  0.0009938503261272622,
#  0.0009999999999999911,
#  0.0009938503261272625,
#  0.0009755527298894205,
#  0.0009455577588320819,
#  0.0009046039886902785,
#  0.0008536998372026741,
#  0.0007940987335200829,
#  0.0007272682546198979,
#  0.0006548539886902807,
#  0.00057863901528759,
#  0.0005004999999999968,
#  0.0004223609847124,
#  0.00034614601130971106,
#  0.00027373174538009395,
#  0.0002069012664799089,
#  0.00014730016279731881,
#  9.639601130971318e-05,
#  5.5442241167909755e-05,
#  2.544727011057043e-05,
#  7.149673872728796e-06,
#  1e-06,
#  7.149673872728684e-06,
#  2.544727011057203e-05,
#  5.544224116791231e-05,
#  9.639601130971784e-05,
#  0.0001473001627973261,
#  0.00020690126647991794,
#  0.00027373174538010956,
#  0.00034614601130972895,
#  0.0004223609847124238,
#  0.0005005000000000214,
#  0.0005786390152876207,
#  0.0006548539886903157,
#  0.0007272682546199368,
#  0.0007940987335201269,
#  0.0008536998372027188,
#  0.0009046039886903274,
#  0.0009455577588321322,
#  0.0009755527298894739,
#  0.0009938503261273162,
#  0.0010000000000000456,
#  0.0009938503261273167,
#  0.0009755527298894744,
#  0.0009455577588321335,
#  0.000904603988690329,
#  0.0008536998372027209,
#  0.0007940987335201263,
#  0.0007272682546199362,
#  0.0006548539886903167,
#  0.0005786390152876219,
#  0.0005005000000000225,
#  0.000422360984712425,
#  0.00034614601130973015,
#  0.0002737317453801106,
#  0.00020690126647992027,
#  0.00014730016279732692,
#  9.639601130971951e-05,
#  5.5442241167912784e-05,
#  2.544727011057182e-05,
#  7.1496738727288545e-06,
#  1e-06,
#  7.149673872728684e-06,
#  2.544727011057037e-05,
#  5.5442241167909796e-05,
#  9.639601130971342e-05,
#  0.00014730016279731816,
#  0.0002069012664799085,
#  0.00027373174538009715,
#  0.000346146011309715,
#  0.0004223609847124046,
#  0.0005005000000000004,
#  0.0005786390152875945,
#  0.0006548539886902858,
#  0.0007272682546199036,
#  0.0007940987335200892,
#  0.0008536998372026799,
#  0.000904603988690285,
#  0.000945557758832089,
#  0.0009755527298894294,
#  0.0009938503261272714,
#  0.0009999999999999998,
#  0.0009938503261272711,
#  0.0009755527298894291,
#  0.0009455577588320901,
#  0.0009046039886902875,
#  0.0008536998372026818,
#  0.0007940987335200915,
#  0.0007272682546199046,
#  0.0006548539886902868,
#  0.0005786390152875954,
#  0.0005004999999999998,
#  0.00042236098471240394,
#  0.0003461460113097127,
#  0.0002737317453800982,
#  0.00020690126647991092,
#  0.0001473001627973203,
#  9.639601130971411e-05,
#  5.544224116791033e-05,
#  2.5447270110571804e-05,
#  7.149673872728627e-06,
#  1e-06,
#  7.149673872728684e-06,
#  2.5447270110569215e-05,
#  5.544224116790729e-05,
#  9.639601130970907e-05,
#  0.00014730016279731274,
#  0.0002069012664799006,
#  0.0002737317453800816,
#  0.000346146011309696,
#  0.0004223609847123838,
#  0.0005004999999999797,
#  0.0005786390152875683,
#  0.0006548539886902563,
#  0.0007272682546198709,
#  0.0007940987335200549,
#  0.0008536998372026428,
#  0.0009046039886902443,
#  0.0009455577588320467,
#  0.0009755527298893852,
#  0.0009938503261272267,
#  0.0009999999999999554,
#  0.000993850326127227,
#  0.0009755527298893858,
#  0.0009455577588320474,
#  0.0009046039886902453,
#  0.000853699837202644,
#  0.0007940987335200564,
#  0.0007272682546198724,
#  0.0006548539886902578,
#  0.00057863901528757,
#  0.0005004999999999812,
#  0.0004223609847123854,
#  0.00034614601130969746,
#  0.00027373174538008294,
#  0.00020690126647990181,
#  0.00014730016279731385,
#  9.639601130970994e-05,
#  5.544224116790798e-05,
#  2.544727011056967e-05,
#  7.1496738727289096e-06,
#  1e-06,
#  7.149673872728684e-06,
#  2.544727011057269e-05,
#  5.544224116791263e-05,
#  9.639601130971846e-05,
#  0.0001473001627973272,
#  0.0002069012664799209,
#  0.0002737317453801117,
#  0.00034614601130973004,
#  0.0004223609847124254,
#  0.0005005000000000253,
#  0.0005786390152876254,
#  0.000654853988690321,
#  0.0007272682546199426,
#  0.0007940987335201334,
#  0.0008536998372027273,
#  0.0009046039886903358,
#  0.0009455577588321401,
#  0.0009755527298894816,
#  0.000993850326127325,
#  0.0010000000000000542,
#  0.0009938503261273251,
#  0.0009755527298894834,
#  0.0009455577588321409,
#  0.0009046039886903349,
#  0.000853699837202726,
#  0.000794098733520135,
#  0.0007272682546199444,
#  0.0006548539886903227,
#  0.0005786390152876271,
#  0.0005005000000000272,
#  0.00042236098471243067,
#  0.0003461460113097351,
#  0.00027373174538011325,
#  0.00020690126647991943,
#  0.0001473001627973284,
#  9.63960113097195e-05,
#  5.544224116791342e-05,
#  2.5447270110572142e-05,
#  7.149673872728963e-06,
#  1e-06]

# %%
plot_lr('CosCosineAnnealingLR', lr_list)

# %% [markdown]
# #### CosineAnnealingWarmRestarts
#
# cosine annealing의 스케쥴링에 cosine 주기의 에폭을 점점 늘리거나 줄일 수 있다. (보통 늘린다.)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
cawr_lr_sche = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optimizer,
    T_0=10,      # 변화주기 (CosineAnnealingLR의 T_max)
    T_mult=2,    # 새로운 변화주기(새변화주기(T_0) = 현재 변화주기(T_0) * T_mult)
    eta_min=1e-6,
)

# %%
lr_list = []
for epoch in range(epochs):
    for step in range(step_size):
        optimizer.step()
        optimizer.zero_grad()
    cawr_lr_sche.step()
    lr_list.append(cawr_lr_sche.get_last_lr()[0])

# %%
lr_list[0]
# Out:
# 0.0009755527298894294

# %%
plot_lr('CosineAnnealingWarmRestarts', lr_list)
